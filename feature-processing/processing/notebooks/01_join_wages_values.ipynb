# %% [markdown]
# This notebook deals with creating a dataset that combines the player wage and valuations data which will be the predictor variables for our model.|

# %%
import sys
from pathlib import Path
nb_path = Path.cwd().parent.parent 
sys.path.insert(0, str(nb_path))

import pandas as pd

# google cloud storage
from processing.gcp.storage import gcp 

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Wages

# %%
def load_wages(league: str) -> pd.DataFrame:
    return gcp.read_df_from_bucket(
        bucket_name="processed_fbref_db", blob_name=f"processed_{league}-wages.csv"
    )

# %%
prem_wages = load_wages("Premier-League")
# Out:
# [03/18/24 16:55:03] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=420870;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=733403;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
# [03/18/24 16:55:04] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=522244;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=509358;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
prem_wages.head()
# Out:
#    rk              player nation    pos    squad  age  weekly_wages_euros  \
# 0   1      Alexis Sánchez    CHI  MF,FW  Arsenal   28              402897
# 1   2          Mesut Özil    GER  MF,FW  Arsenal   28              402897
# 2   3         Eden Hazard    BEL  FW,MF  Chelsea   26              256548
# 3   4       Cesc Fàbregas    ESP     MF  Chelsea   30              236735
# 4   5  Henrikh Mkhitaryan    ARM  FW,MF  Arsenal   28              230227
#
#    annual_wages_euros                  notes     season general_pos age_range  \
# 0            20950637  Unverified estimation  2017-2018  Midfielder     25-29
# 1            20950637  Unverified estimation  2017-2018  Midfielder     25-29
# 2            13340491  Unverified estimation  2017-2018     Forward     25-29
# 3            12310226  Unverified estimation  2017-2018  Midfielder     30-34
# 4            11971793  Unverified estimation  2017-2018     Forward     25-29
#
#    country      continent  player_id
# 0    Chile  South America     2111.0
# 1  Germany         Europe     1796.0
# 2  Belgium         Europe     1003.0
# 3    Spain         Europe      744.0
# 4  Armenia           Asia     1608.0

# %%
prem_wages.shape
# Out:
# (4048, 15)

# %%
prem_wages.nunique()
# Out:
# rk                     638
# player                1564
# nation                  97
# pos                     22
# squad                   30
# age                     26
# weekly_wages_euros     642
# annual_wages_euros     644
# notes                    1
# season                   7
# general_pos              5
# age_range                6
# country                 96
# continent                7
# player_id             1332
# dtype: int64

# %%
prem_wages['pos'].unique()
# Out:
# array(['MF,FW', 'FW,MF', 'MF', 'GK', 'FW', 'DF', nan, 'DF,MF', 'DF,FW',
#        'FW,DF', 'MF,DF', 'CB', 'RW', 'CM', 'RB', 'DF,GK', 'SS', 'LB',
#        'LW', 'CF', 'AM', 'DM', 'LM'], dtype=object)

# %% [markdown]
# ## Values

# %%
def load_valuations(league: str) -> pd.DataFrame:
    return gcp.read_df_from_bucket(
        bucket_name="processed_transfermarkt_db", blob_name=f"processed_{league}_player_valuations.csv"
    )

# %%
prem_values = load_valuations("premier_league")
# Out:
# [03/18/24 18:34:14] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=155074;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=239772;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
# [03/18/24 18:34:15] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=823218;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=431755;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
prem_values.head()
# Out:
#     tm_id        tm_name         player  squad_num     position  age  \
# 0  238223        ederson        Ederson         31   Goalkeeper   24
# 1   40204       joe-hart       Joe Hart          0   Goalkeeper   31
# 2   40423  claudio-bravo  Claudio Bravo          1   Goalkeeper   35
# 3  201574     angus-gunn     Angus Gunn         54   Goalkeeper   22
# 4  186590    john-stones    John Stones          5  Centre-Back   24
#
#     country         current_club  height   foot   signed_date  \
# 0    Brazil      Manchester City   188.0   left   Jul 1, 2017
# 1   England            Celtic FC   196.0  right   Jul 1, 2006
# 2     Chile  Real Betis Balompié   184.0  right  Aug 25, 2016
# 3  Scotland         Norwich City   196.0  right   Jul 1, 2016
# 4   England      Manchester City   188.0  right   Aug 9, 2016
#
#            signed_from  signing_fee_euro_mill contract_expiry  \
# 0           SL Benfica                   40.0             NaN
# 1      Shrewsbury Town                    0.9             NaN
# 2         FC Barcelona                   18.0             NaN
# 3  Manchester City U23                    NaN             NaN
# 4           Everton FC                   55.6             NaN
#
#    market_value_euro_mill  season          league             team  \
# 0                    50.0    2017  premier_league  manchester-city
# 1                    10.0    2017  premier_league  manchester-city
# 2                     3.5    2017  premier_league  manchester-city
# 3                     2.0    2017  premier_league  manchester-city
# 4                    50.0    2017  premier_league  manchester-city
#
#    signed_year  player_id
# 0       2017.0      709.0
# 1       2006.0      998.0
# 2       2016.0      339.0
# 3       2016.0     2853.0
# 4       2016.0     2274.0

# %%
prem_values['position'].unique()
# Out:
# array(['Goalkeeper', 'Centre-Back', 'Left-Back', 'Right-Back',
#        'Defensive-Midfield', 'Central-Midfield', 'Attacking-Midfield',
#        'Left-Winger', 'Right-Winger', 'Centre-Forward', 'Right-Midfield',
#        'Left-Midfield', 'Second-Striker'], dtype=object)

# %%
prem_values['team'].str.replace('^(a?fc)-', '', regex=True).unique()
# Out:
# array(['manchester-city', 'chelsea', 'liverpool', 'manchester-united',
#        'tottenham-hotspur', 'arsenal', 'everton', 'leicester-city',
#        'southampton', 'west-ham-united', 'crystal-palace',
#        'newcastle-united', 'watford', 'stoke-city', 'burnley',
#        'west-bromwich-albion', 'swansea-city', 'brighton-amp-hove-albion',
#        'bournemouth', 'huddersfield-town', 'wolverhampton-wanderers',
#        'fulham', 'cardiff-city', 'aston-villa', 'norwich-city',
#        'sheffield-united', 'leeds-united', 'brentford',
#        'nottingham-forest', 'luton-town'], dtype=object)

# %%
prem_values.loc[:, 'team'] = prem_values['team'].str.replace('-', ' ').str.replace('a?fc ', '', regex=True)

# %%
# compare team names
val_teams = prem_values['team'].unique()
len(val_teams)
# Out:
# 30

# %%
wage_teams = prem_wages['squad'].unique()
len(wage_teams)
# Out:
# 30

# %%
val_teams.sort()
val_teams
# Out:
# array(['arsenal', 'aston villa', 'bournemouth', 'brentford',
#        'brighton amp hove albion', 'burnley', 'cardiff city', 'chelsea',
#        'crystal palace', 'everton', 'fulham', 'huddersfield town',
#        'leeds united', 'leicester city', 'liverpool', 'luton town',
#        'manchester city', 'manchester united', 'newcastle united',
#        'norwich city', 'nottingham forest', 'sheffield united',
#        'southampton', 'stoke city', 'swansea city', 'tottenham hotspur',
#        'watford', 'west bromwich albion', 'west ham united',
#        'wolverhampton wanderers'], dtype=object)

# %%
wage_teams.sort()
wage_teams
# Out:
# array(['Arsenal', 'Aston Villa', 'Bournemouth', 'Brentford', 'Brighton',
#        'Burnley', 'Cardiff City', 'Chelsea', 'Crystal Palace', 'Everton',
#        'Fulham', 'Huddersfield', 'Leeds United', 'Leicester City',
#        'Liverpool', 'Luton Town', 'Manchester City', 'Manchester Utd',
#        'Newcastle Utd', 'Norwich City', "Nott'ham Forest",
#        'Sheffield Utd', 'Southampton', 'Stoke City', 'Swansea City',
#        'Tottenham', 'Watford', 'West Brom', 'West Ham', 'Wolves'],
#       dtype=object)

# %%
team_dict = dict(zip(val_teams, wage_teams))

# %%
# change team names in valuations df
def change_team_names(df: pd.DataFrame, team_dict: dict) -> pd.DataFrame:
    df.loc[:, 'team'] = df['team'].map(team_dict)
    return df

# %%
prem_values = change_team_names(prem_values, team_dict)

# %%
prem_values.head()
# Out:
#     tm_id        tm_name         player  squad_num     position  age  \
# 0  238223        ederson        Ederson         31   Goalkeeper   24
# 1   40204       joe-hart       Joe Hart          0   Goalkeeper   31
# 2   40423  claudio-bravo  Claudio Bravo          1   Goalkeeper   35
# 3  201574     angus-gunn     Angus Gunn         54   Goalkeeper   22
# 4  186590    john-stones    John Stones          5  Centre-Back   24
#
#     country         current_club  height   foot   signed_date  \
# 0    Brazil      Manchester City   188.0   left   Jul 1, 2017
# 1   England            Celtic FC   196.0  right   Jul 1, 2006
# 2     Chile  Real Betis Balompié   184.0  right  Aug 25, 2016
# 3  Scotland         Norwich City   196.0  right   Jul 1, 2016
# 4   England      Manchester City   188.0  right   Aug 9, 2016
#
#            signed_from  signing_fee_euro_mill contract_expiry  \
# 0           SL Benfica                   40.0             NaN
# 1      Shrewsbury Town                    0.9             NaN
# 2         FC Barcelona                   18.0             NaN
# 3  Manchester City U23                    NaN             NaN
# 4           Everton FC                   55.6             NaN
#
#    market_value_euro_mill  season          league             team  \
# 0                    50.0    2017  premier_league  Manchester City
# 1                    10.0    2017  premier_league  Manchester City
# 2                     3.5    2017  premier_league  Manchester City
# 3                     2.0    2017  premier_league  Manchester City
# 4                    50.0    2017  premier_league  Manchester City
#
#    signed_year  player_id
# 0       2017.0      709.0
# 1       2006.0      998.0
# 2       2016.0      339.0
# 3       2016.0     2853.0
# 4       2016.0     2274.0

# %% [markdown]
# ## Join wages and valuations

# %% [markdown]
# ## Premier League

# %%
# redefine season variable for wages to match values season
def redefine_season(df: pd.DataFrame) -> pd.DataFrame:
    df.loc[:, 'season'] = df['season'].apply(lambda x: x.split('-')[0]).astype(int)
    return df

# %%
prem_wages = redefine_season(prem_wages)

# %%
prem_wages.head()
# Out:
#    rk              player nation    pos    squad  age  weekly_wages_euros  \
# 0   1      Alexis Sánchez    CHI  MF,FW  Arsenal   28              402897
# 1   2          Mesut Özil    GER  MF,FW  Arsenal   28              402897
# 2   3         Eden Hazard    BEL  FW,MF  Chelsea   26              256548
# 3   4       Cesc Fàbregas    ESP     MF  Chelsea   30              236735
# 4   5  Henrikh Mkhitaryan    ARM  FW,MF  Arsenal   28              230227
#
#    annual_wages_euros                  notes season general_pos age_range  \
# 0            20950637  Unverified estimation   2017  Midfielder     25-29
# 1            20950637  Unverified estimation   2017  Midfielder     25-29
# 2            13340491  Unverified estimation   2017     Forward     25-29
# 3            12310226  Unverified estimation   2017  Midfielder     30-34
# 4            11971793  Unverified estimation   2017     Forward     25-29
#
#    country      continent  player_id
# 0    Chile  South America     2111.0
# 1  Germany         Europe     1796.0
# 2  Belgium         Europe     1003.0
# 3    Spain         Europe      744.0
# 4  Armenia           Asia     1608.0

# %%
# remove columns that are not needed
def drop_wage_columns(df: pd.DataFrame) -> pd.DataFrame:
    wage_cols_to_drop = ["nation", "pos", "notes", "rk", "general_pos", "country"]
    return df.drop(columns=wage_cols_to_drop)

# %%
prem_wages = drop_wage_columns(prem_wages)

# %%
# same for values
prem_values.head()
# Out:
#     tm_id        tm_name         player  squad_num     position  age  \
# 0  238223        ederson        Ederson         31   Goalkeeper   24
# 1   40204       joe-hart       Joe Hart          0   Goalkeeper   31
# 2   40423  claudio-bravo  Claudio Bravo          1   Goalkeeper   35
# 3  201574     angus-gunn     Angus Gunn         54   Goalkeeper   22
# 4  186590    john-stones    John Stones          5  Centre-Back   24
#
#     country         current_club  height   foot   signed_date  \
# 0    Brazil      Manchester City   188.0   left   Jul 1, 2017
# 1   England            Celtic FC   196.0  right   Jul 1, 2006
# 2     Chile  Real Betis Balompié   184.0  right  Aug 25, 2016
# 3  Scotland         Norwich City   196.0  right   Jul 1, 2016
# 4   England      Manchester City   188.0  right   Aug 9, 2016
#
#            signed_from  signing_fee_euro_mill contract_expiry  \
# 0           SL Benfica                   40.0             NaN
# 1      Shrewsbury Town                    0.9             NaN
# 2         FC Barcelona                   18.0             NaN
# 3  Manchester City U23                    NaN             NaN
# 4           Everton FC                   55.6             NaN
#
#    market_value_euro_mill  season          league             team  \
# 0                    50.0    2017  premier_league  Manchester City
# 1                    10.0    2017  premier_league  Manchester City
# 2                     3.5    2017  premier_league  Manchester City
# 3                     2.0    2017  premier_league  Manchester City
# 4                    50.0    2017  premier_league  Manchester City
#
#    signed_year  player_id
# 0       2017.0      709.0
# 1       2006.0      998.0
# 2       2016.0      339.0
# 3       2016.0     2853.0
# 4       2016.0     2274.0

# %%
def drop_value_columns(df: pd.DataFrame) -> pd.DataFrame:
    val_cols_to_drop = ['tm_id', 'tm_name', 'squad_num', 'contract_expiry', 'current_club', 'signed_date']
    return df.drop(columns=val_cols_to_drop)

# %%
prem_values = drop_value_columns(prem_values)

# %%
prem_values.head()
# Out:
#           player     position  age   country  height   foot  \
# 0        Ederson   Goalkeeper   24    Brazil   188.0   left
# 1       Joe Hart   Goalkeeper   31   England   196.0  right
# 2  Claudio Bravo   Goalkeeper   35     Chile   184.0  right
# 3     Angus Gunn   Goalkeeper   22  Scotland   196.0  right
# 4    John Stones  Centre-Back   24   England   188.0  right
#
#            signed_from  signing_fee_euro_mill  market_value_euro_mill  season  \
# 0           SL Benfica                   40.0                    50.0    2017
# 1      Shrewsbury Town                    0.9                    10.0    2017
# 2         FC Barcelona                   18.0                     3.5    2017
# 3  Manchester City U23                    NaN                     2.0    2017
# 4           Everton FC                   55.6                    50.0    2017
#
#            league             team  signed_year  player_id
# 0  premier_league  Manchester City       2017.0      709.0
# 1  premier_league  Manchester City       2006.0      998.0
# 2  premier_league  Manchester City       2016.0      339.0
# 3  premier_league  Manchester City       2016.0     2853.0
# 4  premier_league  Manchester City       2016.0     2274.0

# %%
def join_wages_values(wages_df: pd.DataFrame, values_df: pd.DataFrame) -> pd.DataFrame:
    return pd.merge(
        left=wages_df,
        right=values_df,
        how="inner",
        left_on=["player", "season", "squad"],
        right_on=["player", "season", "team"],
        suffixes=("_wage_df", "_value_df"),
    )

# %%
prem_join = join_wages_values(prem_wages, prem_values)

# %%
prem_join.head()
# Out:
#                player    squad  age_wage_df  weekly_wages_euros  \
# 0      Alexis Sánchez  Arsenal           28              402897
# 1          Mesut Özil  Arsenal           28              402897
# 2         Eden Hazard  Chelsea           26              256548
# 3       Cesc Fàbregas  Chelsea           30              236735
# 4  Henrikh Mkhitaryan  Arsenal           28              230227
#
#    annual_wages_euros season age_range      continent  player_id_wage_df  \
# 0            20950637   2017     25-29  South America             2111.0
# 1            20950637   2017     25-29         Europe             1796.0
# 2            13340491   2017     25-29         Europe             1003.0
# 3            12310226   2017     30-34         Europe              744.0
# 4            11971793   2017     25-29           Asia             1608.0
#
#              position  age_value_df  country  height   foot  \
# 0      Centre-Forward            29    Chile   169.0  right
# 1  Attacking-Midfield            29  Germany   180.0   left
# 2         Left-Winger            27  Belgium   175.0  right
# 3    Central-Midfield            31    Spain   179.0  right
# 4    Central-Midfield            29  Armenia   177.0   both
#
#          signed_from  signing_fee_euro_mill  market_value_euro_mill  \
# 0       FC Barcelona                   42.5                    70.0
# 1        Real Madrid                   47.0                    50.0
# 2         LOSC Lille                   35.0                   110.0
# 3       FC Barcelona                   33.0                    30.0
# 4  Manchester United                   34.0                    35.0
#
#            league     team  signed_year  player_id_value_df
# 0  premier_league  Arsenal       2014.0              2111.0
# 1  premier_league  Arsenal       2013.0              1796.0
# 2  premier_league  Chelsea       2012.0              1003.0
# 3  premier_league  Chelsea       2014.0               744.0
# 4  premier_league  Arsenal       2018.0              1608.0

# %%
# check join
prem_join.loc[prem_join['player'] == 'Mesut Özil']
# Out:
#           player    squad  age_wage_df  weekly_wages_euros  \
# 1     Mesut Özil  Arsenal           28              402897
# 550   Mesut Özil  Arsenal           29              407470
# 1138  Mesut Özil  Arsenal           30              417398
#
#       annual_wages_euros season age_range continent  player_id_wage_df  \
# 1               20950637   2017     25-29    Europe             1796.0
# 550             21188462   2018     25-29    Europe             1796.0
# 1138            21704678   2019     30-34    Europe             1796.0
#
#                 position  age_value_df  country  height  foot  signed_from  \
# 1     Attacking-Midfield            29  Germany   180.0  left  Real Madrid
# 550   Attacking-Midfield            30  Germany   180.0  left  Real Madrid
# 1138  Attacking-Midfield            31  Germany   180.0  left  Real Madrid
#
#       signing_fee_euro_mill  market_value_euro_mill          league     team  \
# 1                      47.0                    50.0  premier_league  Arsenal
# 550                    47.0                    25.0  premier_league  Arsenal
# 1138                   47.0                    17.5  premier_league  Arsenal
#
#       signed_year  player_id_value_df
# 1          2013.0              1796.0
# 550        2013.0              1796.0
# 1138       2013.0              1796.0

# %%
def sort_columns(df: pd.DataFrame) -> pd.DataFrame:
    # remove duplicate cols
    cols = [col for col in df.columns if '_value_df' not in col]
    df = df[cols]
    
    # rename columns
    df.columns = [col.replace('_wage_df', '') for col in df.columns]
    
    # drop team column
    return df.drop(columns=['team'])

# %%
prem_join = sort_columns(prem_join)

# %%
prem_join.head()
# Out:
#                player    squad  age  weekly_wages_euros  annual_wages_euros  \
# 0      Alexis Sánchez  Arsenal   28              402897            20950637
# 1          Mesut Özil  Arsenal   28              402897            20950637
# 2         Eden Hazard  Chelsea   26              256548            13340491
# 3       Cesc Fàbregas  Chelsea   30              236735            12310226
# 4  Henrikh Mkhitaryan  Arsenal   28              230227            11971793
#
#   season age_range      continent  player_id            position  country  \
# 0   2017     25-29  South America     2111.0      Centre-Forward    Chile
# 1   2017     25-29         Europe     1796.0  Attacking-Midfield  Germany
# 2   2017     25-29         Europe     1003.0         Left-Winger  Belgium
# 3   2017     30-34         Europe      744.0    Central-Midfield    Spain
# 4   2017     25-29           Asia     1608.0    Central-Midfield  Armenia
#
#    height   foot        signed_from  signing_fee_euro_mill  \
# 0   169.0  right       FC Barcelona                   42.5
# 1   180.0   left        Real Madrid                   47.0
# 2   175.0  right         LOSC Lille                   35.0
# 3   179.0  right       FC Barcelona                   33.0
# 4   177.0   both  Manchester United                   34.0
#
#    market_value_euro_mill          league  signed_year
# 0                    70.0  premier_league       2014.0
# 1                    50.0  premier_league       2013.0
# 2                   110.0  premier_league       2012.0
# 3                    30.0  premier_league       2014.0
# 4                    35.0  premier_league       2018.0

# %%
prem_join
# Out:
#                   player        squad  age  weekly_wages_euros  \
# 0         Alexis Sánchez      Arsenal   28              402897
# 1             Mesut Özil      Arsenal   28              402897
# 2            Eden Hazard      Chelsea   26              256548
# 3          Cesc Fàbregas      Chelsea   30              236735
# 4     Henrikh Mkhitaryan      Arsenal   28              230227
# ...                  ...          ...  ...                 ...
# 3679        Joseph Anang     West Ham   23                4654
# 3680         Enock Agyei      Burnley   18                4654
# 3681       Denis Franchi      Burnley   20                3490
# 3682        Jordan Beyer      Burnley   23                3490
# 3683      Gavin Kilkenny  Bournemouth   23                1745
#
#       annual_wages_euros season age_range      continent  player_id  \
# 0               20950637   2017     25-29  South America     2111.0
# 1               20950637   2017     25-29         Europe     1796.0
# 2               13340491   2017     25-29         Europe     1003.0
# 3               12310226   2017     30-34         Europe      744.0
# 4               11971793   2017     25-29           Asia     1608.0
# ...                  ...    ...       ...            ...        ...
# 3679              241990   2023     20-24        Unknown        NaN
# 3680              241990   2023  Under 20        Unknown        NaN
# 3681              181492   2023     20-24         Europe        NaN
# 3682              181492   2023     20-24         Europe     2636.0
# 3683               90746   2023     20-24         Europe        NaN
#
#                 position  country  height   foot               signed_from  \
# 0         Centre-Forward    Chile   169.0  right              FC Barcelona
# 1     Attacking-Midfield  Germany   180.0   left               Real Madrid
# 2            Left-Winger  Belgium   175.0  right                LOSC Lille
# 3       Central-Midfield    Spain   179.0  right              FC Barcelona
# 4       Central-Midfield  Armenia   177.0   both         Manchester United
# ...                  ...      ...     ...    ...                       ...
# 3679          Goalkeeper  England   190.0  right       West Ham United U21
# 3680        Right-Winger  Belgium   172.0   left              RSCA Futures
# 3681          Goalkeeper    Italy   189.0  right       Paris Saint-Germain
# 3682         Centre-Back  Germany   187.0  right  Borussia Mönchengladbach
# 3683    Central-Midfield  Ireland   175.0  right       AFC Bournemouth U21
#
#       signing_fee_euro_mill  market_value_euro_mill          league  \
# 0                     42.50                   70.00  premier_league
# 1                     47.00                   50.00  premier_league
# 2                     35.00                  110.00  premier_league
# 3                     33.00                   30.00  premier_league
# 4                     34.00                   35.00  premier_league
# ...                     ...                     ...             ...
# 3679                    NaN                    0.30  premier_league
# 3680                   0.35                    0.80  premier_league
# 3681                    NaN                    0.25  premier_league
# 3682                  15.00                   16.00  premier_league
# 3683                    NaN                    0.30  premier_league
#
#       signed_year
# 0          2014.0
# 1          2013.0
# 2          2012.0
# 3          2014.0
# 4          2018.0
# ...           ...
# 3679       2023.0
# 3680       2023.0
# 3681       2022.0
# 3682       2023.0
# 3683       2020.0
#
# [3684 rows x 18 columns]

# %% [markdown]
# ## La liga Join

# %%
# load wages
la_liga_wages = load_wages("La-Liga")
# Out:
# [03/18/24 16:55:06] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=153143;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=980919;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=734327;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=686794;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
la_liga_wages.head()
# Out:
#    rk             player nation    pos        squad  age  weekly_wages_euros  \
# 0   1       Lionel Messi    ARG     FW    Barcelona   30              761923
# 1   2  Cristiano Ronaldo    POR     FW  Real Madrid   32              670192
# 2   3      Samuel Umtiti    FRA     DF    Barcelona   23              615385
# 3   4       Gerard Piqué    ESP     DF    Barcelona   30              546154
# 4   5        Gareth Bale    WAL  FW,MF  Real Madrid   28              532308
#
#    annual_wages_euros                  notes     season general_pos age_range  \
# 0            39620000  Unverified estimation  2017-2018     Forward     30-34
# 1            34850000  Unverified estimation  2017-2018     Forward     30-34
# 2            32000000  Unverified estimation  2017-2018    Defender     20-24
# 3            28400000  Unverified estimation  2017-2018    Defender     30-34
# 4            27680000  Unverified estimation  2017-2018     Forward     25-29
#
#      country      continent  player_id
# 0  Argentina  South America     1580.0
# 1   Portugal         Europe     2040.0
# 2     France         Europe     2395.0
# 3      Spain         Europe     1883.0
# 4      Wales         Europe      168.0

# %%
# load values
la_liga_values = load_valuations("la_liga")
# Out:
# [03/18/24 16:55:08] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=963538;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=323107;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=862135;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=302598;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
la_liga_values.head()
# Out:
#     tm_id                tm_name                 player  squad_num  \
# 0   74857  marc-andre-ter-stegen  Marc-André ter Stegen          1
# 1  146227       jasper-cillessen       Jasper Cillessen         13
# 2  142033          adrian-ortola          Adrián Ortolá         31
# 3  126540          samuel-umtiti          Samuel Umtiti         23
# 4   18944           gerard-pique           Gerard Piqué          3
#
#       position  age      country    current_club  height   foot   signed_date  \
# 0   Goalkeeper   26      Germany    FC Barcelona   187.0  right   Jul 1, 2014
# 1   Goalkeeper   29  Netherlands    NEC Nijmegen   187.0  right  Aug 25, 2016
# 2   Goalkeeper   24        Spain  CE Sabadell FC   187.0   left   Jul 1, 2018
# 3  Centre-Back   24       France      LOSC Lille   182.0   left  Jul 14, 2016
# 4  Centre-Back   31        Spain         Retired   194.0  right   Jul 1, 2008
#
#                 signed_from  signing_fee_euro_mill contract_expiry  \
# 0  Borussia Mönchengladbach                   12.0             NaN
# 1            Ajax Amsterdam                   13.0             NaN
# 2            FC Barcelona B                    NaN             NaN
# 3            Olympique Lyon                   25.0             NaN
# 4         Manchester United                    5.0             NaN
#
#    market_value_euro_mill  season   league          team  signed_year  \
# 0                    60.0    2017  la_liga  fc-barcelona       2014.0
# 1                     9.0    2017  la_liga  fc-barcelona       2016.0
# 2                     1.5    2017  la_liga  fc-barcelona       2018.0
# 3                    60.0    2017  la_liga  fc-barcelona       2016.0
# 4                    50.0    2017  la_liga  fc-barcelona       2008.0
#
#    player_id
# 0     2325.0
# 1      489.0
# 2        NaN
# 3     2395.0
# 4     1883.0

# %%
# rename betis to real betis
la_liga_wages.loc[:, 'squad'] = la_liga_wages['squad'].replace('Betis', 'Real Betis')
la_liga_wages.loc[:, 'squad'] = la_liga_wages['squad'].replace('Valladolid', 'Real Valladolid')
la_liga_wages.loc[:, 'squad'] = la_liga_wages['squad'].replace('Málaga', 'Malaga')
la_liga_wages.loc[:, 'squad'] = la_liga_wages['squad'].replace('Cádiz', 'Cadiz')

# %%
# change team names in values df with names from wages df
liga_wage_teams = la_liga_wages['squad'].unique()
liga_wage_teams.sort()

# %%
la_liga_values.loc[:, 'team'] = la_liga_values['team'].str.replace('^(fc|sd|rcd|ca|ud|cd|deportivo)-', '', regex=True)

# %%
liga_values_teams = la_liga_values['team'].unique()
liga_values_teams.sort()

# %%
liga_team_dict = dict(zip(liga_values_teams, liga_wage_teams))

# %%
la_liga_values = change_team_names(la_liga_values, liga_team_dict)

# %%
la_liga_values.head()
# Out:
#     tm_id                tm_name                 player  squad_num  \
# 0   74857  marc-andre-ter-stegen  Marc-André ter Stegen          1
# 1  146227       jasper-cillessen       Jasper Cillessen         13
# 2  142033          adrian-ortola          Adrián Ortolá         31
# 3  126540          samuel-umtiti          Samuel Umtiti         23
# 4   18944           gerard-pique           Gerard Piqué          3
#
#       position  age      country    current_club  height   foot   signed_date  \
# 0   Goalkeeper   26      Germany    FC Barcelona   187.0  right   Jul 1, 2014
# 1   Goalkeeper   29  Netherlands    NEC Nijmegen   187.0  right  Aug 25, 2016
# 2   Goalkeeper   24        Spain  CE Sabadell FC   187.0   left   Jul 1, 2018
# 3  Centre-Back   24       France      LOSC Lille   182.0   left  Jul 14, 2016
# 4  Centre-Back   31        Spain         Retired   194.0  right   Jul 1, 2008
#
#                 signed_from  signing_fee_euro_mill contract_expiry  \
# 0  Borussia Mönchengladbach                   12.0             NaN
# 1            Ajax Amsterdam                   13.0             NaN
# 2            FC Barcelona B                    NaN             NaN
# 3            Olympique Lyon                   25.0             NaN
# 4         Manchester United                    5.0             NaN
#
#    market_value_euro_mill  season   league       team  signed_year  player_id
# 0                    60.0    2017  la_liga  Barcelona       2014.0     2325.0
# 1                     9.0    2017  la_liga  Barcelona       2016.0      489.0
# 2                     1.5    2017  la_liga  Barcelona       2018.0        NaN
# 3                    60.0    2017  la_liga  Barcelona       2016.0     2395.0
# 4                    50.0    2017  la_liga  Barcelona       2008.0     1883.0

# %% [markdown]
# ## Join la liga wages and values

# %%
la_liga_wages = la_liga_wages.pipe(redefine_season).pipe(drop_wage_columns)

# %%
la_liga_values = drop_value_columns(la_liga_values)

# %%
la_liga_join = join_wages_values(la_liga_wages, la_liga_values)

# %%
la_liga_join = sort_columns(la_liga_join)

# %%
la_liga_join.head()
# Out:
#               player        squad  age  weekly_wages_euros  \
# 0       Lionel Messi    Barcelona   30              761923
# 1  Cristiano Ronaldo  Real Madrid   32              670192
# 2      Samuel Umtiti    Barcelona   23              615385
# 3       Gerard Piqué    Barcelona   30              546154
# 4        Gareth Bale  Real Madrid   28              532308
#
#    annual_wages_euros season age_range      continent  player_id  \
# 0            39620000   2017     30-34  South America     1580.0
# 1            34850000   2017     30-34         Europe     2040.0
# 2            32000000   2017     20-24         Europe     2395.0
# 3            28400000   2017     30-34         Europe     1883.0
# 4            27680000   2017     25-29         Europe      168.0
#
#          position    country  height   foot        signed_from  \
# 0    Right-Winger  Argentina   170.0   left     FC Barcelona B
# 1  Centre-Forward   Portugal   187.0  right  Manchester United
# 2     Centre-Back     France   182.0   left     Olympique Lyon
# 3     Centre-Back      Spain   194.0  right  Manchester United
# 4    Right-Winger      Wales   186.0   left  Tottenham Hotspur
#
#    signing_fee_euro_mill  market_value_euro_mill   league  signed_year
# 0                    NaN                   180.0  la_liga       2005.0
# 1                   94.0                   100.0  la_liga       2009.0
# 2                   25.0                    60.0  la_liga       2016.0
# 3                    5.0                    50.0  la_liga       2008.0
# 4                  101.0                    90.0  la_liga       2013.0

# %% [markdown]
# - Can do the same for the remaining datasets, but need to map teams correctly
# - After mapping teams I will create python scripts that deal with joining and loading joined wages and valuations data to gcp bucket

# %% [markdown]
# ## Bundesliga

# %%
bundesliga_wages = load_wages("Bundesliga")
# Out:
# [03/18/24 17:05:04] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=973532;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=91413;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=190832;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=171903;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
bundesliga_values = load_valuations("bundesliga")
# Out:
# [03/18/24 17:05:19] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=318073;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=910284;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=206222;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=413550;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
# map teams 
bundes_wage_teams = bundesliga_wages['squad'].unique()
bundes_wage_teams.sort()

# %%
bundes_values_teams = bundesliga_values['team'].unique()
bundes_values_teams.sort()

# %%
bundes_wage_teams
len(bundes_wage_teams)
# Out:
# 26

# %%
len(bundes_values_teams)
# Out:
# 27

# %%
bundesliga_values.loc[:, 'team'] = bundesliga_values['team'].str.replace('^(1-fc|fc|1-fsv|sv|vfb|sc|vfl|spvgg|tsg-1899|borussia|bayer-04|fortuna)-', '', regex=True)

# %%
bundes_values_teams = bundesliga_values['team'].unique()
bundes_values_teams.sort()

# %%
bundes_wage_teams
# Out:
# array(['Arminia', 'Augsburg', 'Bayern Munich', 'Bochum', 'Darmstadt 98',
#        'Dortmund', 'Düsseldorf', 'Eint Frankfurt', 'Freiburg',
#        'Greuther Fürth', 'Hamburger SV', 'Heidenheim', 'Hertha BSC',
#        'Hoffenheim', 'Köln', 'Leverkusen', "M'Gladbach", 'Mainz 05',
#        'Nürnberg', 'Paderborn 07', 'RB Leipzig', 'Schalke 04',
#        'Stuttgart', 'Union Berlin', 'Werder Bremen', 'Wolfsburg'],
#       dtype=object)

# %%
bundes_values_teams
# Out:
# array(['arminia-bielefeld', 'augsburg', 'bayern-munchen', 'bochum',
#        'darmstadt-98', 'dortmund', 'dusseldorf', 'eintracht-frankfurt',
#        'freiburg', 'greuther-furth', 'hamburger-sv', 'hannover-96',
#        'heidenheim-1846', 'hertha-bsc', 'hoffenheim', 'koln',
#        'leverkusen', 'mainz-05', 'monchengladbach', 'nurnberg',
#        'paderborn-07', 'rasenballsport-leipzig', 'schalke-04',
#        'stuttgart', 'union-berlin', 'werder-bremen', 'wolfsburg'],
#       dtype=object)

# %%
dict(zip(bundes_values_teams, bundes_wage_teams))
# Out:
# {'arminia-bielefeld': 'Arminia',
#  'augsburg': 'Augsburg',
#  'bayern-munchen': 'Bayern Munich',
#  'bochum': 'Bochum',
#  'darmstadt-98': 'Darmstadt 98',
#  'dortmund': 'Dortmund',
#  'dusseldorf': 'Düsseldorf',
#  'eintracht-frankfurt': 'Eint Frankfurt',
#  'freiburg': 'Freiburg',
#  'greuther-furth': 'Greuther Fürth',
#  'hamburger-sv': 'Hamburger SV',
#  'hannover-96': 'Heidenheim',
#  'heidenheim-1846': 'Hertha BSC',
#  'hertha-bsc': 'Hoffenheim',
#  'hoffenheim': 'Köln',
#  'koln': 'Leverkusen',
#  'leverkusen': "M'Gladbach",
#  'mainz-05': 'Mainz 05',
#  'monchengladbach': 'Nürnberg',
#  'nurnberg': 'Paderborn 07',
#  'paderborn-07': 'RB Leipzig',
#  'rasenballsport-leipzig': 'Schalke 04',
#  'schalke-04': 'Stuttgart',
#  'stuttgart': 'Union Berlin',
#  'union-berlin': 'Werder Bremen',
#  'werder-bremen': 'Wolfsburg'}

# %%
# doesn't seem to be hannover in the wage df
bundesliga_wages.loc[bundesliga_wages['season'] == '2017-2018']['squad'].nunique()
# Out:
# 17

# %% [markdown]
# There is no wage data for Hannover 96 - remove them from the valuations data too

# %%
bundesliga_values = bundesliga_values.loc[bundesliga_values['team'] != 'hannover-96']

# %%
# rename monchengladbach in wage df
bundesliga_wages.loc[:, 'squad'] = bundesliga_wages['squad'].replace("M'Gladbach", 'Monchengladbach')

# %%
bundes_wage_teams = bundesliga_wages['squad'].unique()
bundes_wage_teams.sort()

# %%
bundes_values_teams = bundesliga_values['team'].unique()
bundes_values_teams.sort()

# %%
bundes_team_map = dict(zip(bundes_values_teams, bundes_wage_teams))

# %% [markdown]
# ## Serie A

# %%
seriea_wages = load_wages("Serie-A")
# Out:
# [03/18/24 17:43:46] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=328128;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=524977;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=44584;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=957789;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
seriea_wages.head()
# Out:
#    rk                player nation    pos     squad  age  weekly_wages_euros  \
# 0   1      Leonardo Bonucci    ITA     DF     Milan   30              264231
# 1   2       Gonzalo Higuaín    ARG     FW  Juventus   29              264231
# 2   3          Paulo Dybala    ARG  MF,FW  Juventus   23              246731
# 3   4         Douglas Costa    BRA  FW,MF  Juventus   26              211538
# 4   5  Gianluigi Donnarumma    ITA     GK     Milan   18              199808
#
#    annual_wages_euros                  notes     season general_pos age_range  \
# 0            13740000  Unverified estimation  2017-2018    Defender     30-34
# 1            13740000  Unverified estimation  2017-2018     Forward     25-29
# 2            12830000  Unverified estimation  2017-2018  Midfielder     20-24
# 3            11000000  Unverified estimation  2017-2018     Forward     25-29
# 4            10390000  Unverified estimation  2017-2018  Goalkeeper  Under 20
#
#      country      continent  player_id
# 0      Italy         Europe      318.0
# 1  Argentina  South America     1036.0
# 2  Argentina  South America      702.0
# 3     Brazil  South America      536.0
# 4      Italy         Europe      671.0

# %%
seriea_values = load_valuations("serie_a")
# Out:
# [03/18/24 17:44:00] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=41661;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=221469;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=211968;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=972942;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
seriea_values.head()
# Out:
#     tm_id            tm_name             player  squad_num    position  age  \
# 0   44058  wojciech-szczesny  Wojciech Szczesny         23  Goalkeeper   28
# 1    5023   gianluigi-buffon   Gianluigi Buffon          1  Goalkeeper   40
# 2   75411    carlo-pinsoglio    Carlo Pinsoglio         16  Goalkeeper   28
# 3  265079  mattia-del-favero  Mattia Del Favero         32  Goalkeeper   20
# 4  386567     leonardo-loria     Leonardo Loria         35  Goalkeeper   19
#
#   country        current_club  height   foot   signed_date  \
# 0  Poland         Juventus FC   196.0  right  Jul 19, 2017
# 1   Italy             Retired   192.0  right   Jul 4, 2019
# 2   Italy         Juventus FC   194.0   left   Jul 1, 2014
# 3   Italy                SPAL   190.0  right             -
# 4   Italy  Pisa Sporting Club   195.0  right             -
#
#            signed_from  signing_fee_euro_mill contract_expiry  \
# 0           Arsenal FC                   18.0             NaN
# 1  Paris Saint-Germain                    0.0             NaN
# 2       Vicenza Calcio                    0.8             NaN
# 3                  NaN                    0.0             NaN
# 4                  NaN                    0.0             NaN
#
#    market_value_euro_mill  season   league            team  signed_year  \
# 0                    20.0    2017  serie_a  juventus-turin       2017.0
# 1                     2.0    2017  serie_a  juventus-turin       2019.0
# 2                     0.5    2017  serie_a  juventus-turin       2014.0
# 3                     0.1    2017  serie_a  juventus-turin          NaN
# 4                     0.1    2017  serie_a  juventus-turin          NaN
#
#    player_id
# 0        NaN
# 1      359.0
# 2     1882.0
# 3        NaN
# 4        NaN

# %% [markdown]
# ### map teams

# %%
seriea_wage_teams = seriea_wages['squad'].unique()
seriea_wage_teams.sort()
seriea_wage_teams
# Out:
# array(['Atalanta', 'Benevento', 'Bologna', 'Brescia', 'Cagliari',
#        'Chievo', 'Cremonese', 'Crotone', 'Empoli', 'Fiorentina',
#        'Frosinone', 'Genoa', 'Hellas Verona', 'Inter', 'Juventus',
#        'Lazio', 'Lecce', 'Milan', 'Monza', 'Napoli', 'Parma', 'Roma',
#        'SPAL', 'Salernitana', 'Sampdoria', 'Sassuolo', 'Spezia', 'Torino',
#        'Udinese', 'Venezia'], dtype=object)

# %%
seriea_value_teams = seriea_values['team'].unique()
seriea_value_teams.sort()
seriea_value_teams
# Out:
# array(['ac-florenz', 'ac-mailand', 'ac-monza', 'as-rom',
#        'atalanta-bergamo', 'benevento-calcio', 'brescia-calcio',
#        'cagliari-calcio', 'chievo-verona', 'fc-bologna', 'fc-crotone',
#        'fc-empoli', 'fc-turin', 'frosinone-calcio', 'genua-cfc',
#        'hellas-verona', 'inter-mailand', 'juventus-turin', 'lazio-rom',
#        'parma-calcio-1913', 'sampdoria-genua', 'spal', 'spezia-calcio',
#        'ssc-neapel', 'udinese-calcio', 'us-cremonese', 'us-lecce',
#        'us-salernitana-1919', 'us-sassuolo', 'venezia-fc'], dtype=object)

# %%
len(seriea_wage_teams), len(seriea_value_teams)
# Out:
# (30, 30)

# %%
seriea_values.loc[:, 'team'] = seriea_values['team'].str.replace('^(ac|as|fc|ssc|us)-', '', regex=True)

# %%
seriea_value_teams = seriea_values['team'].unique()
seriea_value_teams.sort()
seriea_value_teams
# Out:
# array(['atalanta-bergamo', 'benevento-calcio', 'bologna',
#        'brescia-calcio', 'cagliari-calcio', 'chievo-verona', 'cremonese',
#        'crotone', 'empoli', 'florenz', 'frosinone-calcio', 'genua-cfc',
#        'hellas-verona', 'inter-mailand', 'juventus-turin', 'lazio-rom',
#        'lecce', 'mailand', 'monza', 'neapel', 'parma-calcio-1913', 'rom',
#        'salernitana-1919', 'sampdoria-genua', 'sassuolo', 'spal',
#        'spezia-calcio', 'turin', 'udinese-calcio', 'venezia-fc'],
#       dtype=object)

# %%
seriea_wage_teams = [val.replace('SPAL', 'Spal') for val in seriea_wage_teams]
seriea_wage_teams.sort()
# Out:
# ['Atalanta',
#  'Benevento',
#  'Bologna',
#  'Brescia',
#  'Cagliari',
#  'Chievo',
#  'Cremonese',
#  'Crotone',
#  'Empoli',
#  'Fiorentina',
#  'Frosinone',
#  'Genoa',
#  'Hellas Verona',
#  'Inter',
#  'Juventus',
#  'Lazio',
#  'Lecce',
#  'Milan',
#  'Monza',
#  'Napoli',
#  'Parma',
#  'Roma',
#  'Salernitana',
#  'Sampdoria',
#  'Sassuolo',
#  'Spal',
#  'Spezia',
#  'Torino',
#  'Udinese',
#  'Venezia']

# %%
serie_a_team_map = dict(zip(seriea_value_teams, seriea_wage_teams))

# %% [markdown]
# ## Ligue 1

# %%
ligue1_wages = load_wages("Ligue-1")
# Out:
# [03/18/24 17:58:52] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=839639;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=536093;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
#                     INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=316042;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=310969;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
ligue1_wages.head()
# Out:
#    rk          player nation    pos      squad  age  weekly_wages_euros  \
# 0   1          Neymar    BRA     FW  Paris S-G   25              832692
# 1   2  Edinson Cavani    URU     FW  Paris S-G   30              350769
# 2   3   Kylian Mbappé    FRA  FW,MF     Monaco   18              341731
# 3   4  Lassana Diarra    FRA     MF  Paris S-G   32              330192
# 4   5    Thiago Silva    BRA     DF  Paris S-G   32              303077
#
#    annual_wages_euros                  notes     season general_pos age_range  \
# 0            43300000  Unverified estimation  2017-2018     Forward     25-29
# 1            18240000  Unverified estimation  2017-2018     Forward     30-34
# 2            17770000  Unverified estimation  2017-2018     Forward  Under 20
# 3            17170000  Unverified estimation  2017-2018  Midfielder     30-34
# 4            15760000  Unverified estimation  2017-2018    Defender     30-34
#
#    country      continent  player_id
# 0   Brazil  South America     1715.0
# 1  Uruguay  South America      451.0
# 2   France         Europe     1536.0
# 3   France         Europe      641.0
# 4   Brazil  South America     2203.0

# %%
ligue1_values = load_valuations("ligue_1")
# Out:
# [03/18/24 18:07:33] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:28 ] - Getting GCP bucket                              ]8;id=684632;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=711922;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#28\28]8;;\
# [03/18/24 18:07:34] INFO     processing.gcp.storage - [ MainThread:get_gcp_bucket:33 ] - GCP bucket retrieved                            ]8;id=506343;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py\storage.py]8;;\:]8;id=135131;file:///Users/conal/Projects/fpl_app/feature-processing/processing/gcp/storage.py#33\33]8;;\

# %%
ligue1_values.head()
# Out:
#     tm_id           tm_name            player  squad_num     position  age  \
# 0  120629   alphonse-areola   Alphonse Areola         16   Goalkeeper   25
# 1   45672       kevin-trapp       Kevin Trapp          1   Goalkeeper   27
# 2  282028     remy-descamps     Rémy Descamps          0   Goalkeeper   22
# 3  395251  sebastien-cibois  Sébastien Cibois         40   Goalkeeper   20
# 4  181767        marquinhos        Marquinhos          5  Centre-Back   24
#
#    country         current_club  height   foot   signed_date  \
# 0   France      West Ham United   195.0  right   Jul 1, 2010
# 1  Germany  Eintracht Frankfurt   189.0  right   Jul 8, 2015
# 2   France            FC Nantes   196.0   left   Jul 1, 2017
# 3   France             Rodez AF   192.0  right   Jul 1, 2018
# 4   Brazil  Paris Saint-Germain   183.0  right  Jul 19, 2013
#
#                signed_from  signing_fee_euro_mill contract_expiry  \
# 0  Paris Saint-Germain U19                    NaN             NaN
# 1      Eintracht Frankfurt                    9.5             NaN
# 2    Paris Saint-Germain B                    NaN             NaN
# 3    Paris Saint-Germain B                    NaN             NaN
# 4                  AS Roma                   31.4             NaN
#
#    market_value_euro_mill  season   league                    team  \
# 0                    15.0    2017  ligue_1  fc-paris-saint-germain
# 1                     8.0    2017  ligue_1  fc-paris-saint-germain
# 2                     0.6    2017  ligue_1  fc-paris-saint-germain
# 3                     NaN    2017  ligue_1  fc-paris-saint-germain
# 4                    55.0    2017  ligue_1  fc-paris-saint-germain
#
#    signed_year  player_id
# 0       2010.0      112.0
# 1       2015.0     2381.0
# 2       2017.0     5463.0
# 3       2018.0     4131.0
# 4       2013.0     1492.0

# %% [markdown]
# ### Map teams

# %%
ligue1_wage_teams = ligue1_wages['squad'].unique()
ligue1_wage_teams.sort()
ligue1_wage_teams
# Out:
# array(['Ajaccio', 'Amiens', 'Angers', 'Auxerre', 'Bordeaux', 'Brest',
#        'Caen', 'Clermont Foot', 'Dijon', 'Guingamp', 'Le Havre', 'Lens',
#        'Lille', 'Lorient', 'Lyon', 'Marseille', 'Metz', 'Monaco',
#        'Montpellier', 'Nantes', 'Nice', 'Nîmes', 'Paris S-G', 'Reims',
#        'Rennes', 'Saint-Étienne', 'Strasbourg', 'Toulouse', 'Troyes'],
#       dtype=object)

# %%
ligue1_values['team'].unique()
# Out:
# array(['fc-paris-saint-germain', 'as-monaco', 'olympique-lyon',
#        'olympique-marseille', 'ogc-nizza', 'fc-girondins-bordeaux',
#        'fc-stade-rennes', 'fc-toulouse', 'as-saint-etienne', 'fc-nantes',
#        'losc-lille', 'montpellier-hsc', 'dijon-fco', 'amiens-sc',
#        'sco-angers', 'sm-caen', 'ea-guingamp', 'fc-metz',
#        'rc-strassburg-alsace', 'es-troyes-ac', 'nimes-olympique',
#        'stade-reims', 'stade-brest-29', 'rc-lens', 'fc-lorient',
#        'clermont-foot-63', 'aj-auxerre', 'ac-ajaccio', 'ac-le-havre'],
#       dtype=object)

# %%
ligue1_values.loc[:, 'team'] = ligue1_values['team'].str.replace('^(fc-stade|stade|as|ogc|es|aj|ac|sm|ea|rc|fc-girondins|fc|sco|olympique|losc)-', '', regex=True)

# %%
ligue1_values_teams = ligue1_values['team'].unique()
ligue1_values_teams.sort()
ligue1_values_teams
# Out:
# array(['ajaccio', 'amiens-sc', 'angers', 'auxerre', 'bordeaux',
#        'brest-29', 'caen', 'clermont-foot-63', 'dijon-fco', 'guingamp',
#        'le-havre', 'lens', 'lille', 'lorient', 'lyon', 'marseille',
#        'metz', 'monaco', 'montpellier-hsc', 'nantes', 'nimes-olympique',
#        'nizza', 'paris-saint-germain', 'reims', 'rennes', 'saint-etienne',
#        'strassburg-alsace', 'toulouse', 'troyes-ac'], dtype=object)

# %%
ligue1_values_teams = [val.replace('nizza', 'nice') for val in ligue1_values_teams]
ligue1_values_teams.sort()
ligue1_values_teams
# Out:
# ['ajaccio',
#  'amiens-sc',
#  'angers',
#  'auxerre',
#  'bordeaux',
#  'brest-29',
#  'caen',
#  'clermont-foot-63',
#  'dijon-fco',
#  'guingamp',
#  'le-havre',
#  'lens',
#  'lille',
#  'lorient',
#  'lyon',
#  'marseille',
#  'metz',
#  'monaco',
#  'montpellier-hsc',
#  'nantes',
#  'nice',
#  'nimes-olympique',
#  'paris-saint-germain',
#  'reims',
#  'rennes',
#  'saint-etienne',
#  'strassburg-alsace',
#  'toulouse',
#  'troyes-ac']

# %%
ligue_1_team_map = dict(zip(ligue1_values_teams, ligue1_wage_teams))

# %% [markdown]
# The teams names have been mapped now we can make successful joins between the wage and valuations dfs for each league
